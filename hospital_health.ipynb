# %%
# Load all importance packages
import geopandas
import numpy as np
import pandas as pd
from shapely.geometry import Point

import missingno as msn

import seaborn as sns
import matplotlib.pyplot as plt

% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
# Getting to know GEOJSON file:
hospital = geopandas.read_file("Hospitals_and_Medical_Centers.geojson")

# %%
hospital.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 30 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OBJECTID      165 non-null    int64
#  1   source        143 non-null    object
#  2   ext_id        13 non-null     object
#  3   cat1          165 non-null    object
#  4   cat2          165 non-null    object
#  5   cat3          110 non-null    object
#  6   org_name      133 non-null    object
#  7   Name          165 non-null    object
#  8   addrln1       163 non-null    object
#  9   addrln2       11 non-null     object
#  10  city          163 non-null    object
#  11  state         163 non-null    object
#  12  hours         158 non-null    object
#  13  phones        164 non-null    object
#  14  url           156 non-null    object
#  15  info1         10 non-null     object
#  16  info2         3 non-null      object
#  17  post_id       165 non-null    int64
#  18  description   165 non-null    object
#  19  zip           163 non-null    object
#  20  link          165 non-null    object
#  21  use_type      165 non-null    object
#  22  latitude      165 non-null    float64
#  23  longitude     165 non-null    float64
#  24  date_updated  165 non-null    datetime64[ns, UTC]
#  25  email         6 non-null      object
#  26  dis_status    0 non-null      float64
#  27  POINT_X       165 non-null    float64
#  28  POINT_Y       165 non-null    float64
#  29  geometry      165 non-null    geometry
# dtypes: datetime64[ns, UTC](1), float64(5), geometry(1), int64(2), object(21)
# memory usage: 38.8+ KB

# %%
hospital['source'].unique()
# Out:
# array(['211', 'Current Services Locator',
#        'HSIP Freedom Airports_Heliports',
#        'LA County Department of Health Services',
#        'HSIP Freedom Gnis_structures', nan], dtype=object)

# %%
hospital.drop(columns='ext_id', axis=1)
# Out:
#      OBJECTID source                      cat1                           cat2  \
# 0           9    211  Health and Mental Health  Hospitals and Medical Centers
# 1          11    211  Health and Mental Health  Hospitals and Medical Centers
# 2          20    211  Health and Mental Health  Hospitals and Medical Centers
# 3          25    211  Health and Mental Health  Hospitals and Medical Centers
# 4          35    211  Health and Mental Health  Hospitals and Medical Centers
# ..        ...    ...                       ...                            ...
# 160     71348    NaN  Health and Mental Health  Hospitals and Medical Centers
# 161     71349    NaN  Health and Mental Health  Hospitals and Medical Centers
# 162     71350    NaN  Health and Mental Health  Hospitals and Medical Centers
# 163     71351    NaN  Health and Mental Health  Hospitals and Medical Centers
# 164     71352    NaN  Health and Mental Health  Hospitals and Medical Centers
#
#                      cat3                                           org_name  \
# 0           911 Receiving
# 1    Respiratory Hospital
# 2           911 Receiving
# 3           911 Receiving  Providence Little  Company of Mary Medical Center
# 4           911 Receiving
# ..                    ...                                                ...
# 160                   NaN                                                NaN
# 161         911 Receiving                                                NaN
# 162            Acute Care                                                NaN
# 163                   NaN                                                NaN
# 164            Acute Care                                                NaN
#
#                                                   Name  \
# 0                               Verdugo Hills Hospital
# 1    Barlow Respiratory Hospital - Los Angeles (Mai...
# 2                          Glendora Community Hospital
# 3    Providence Little Company Of Mary Medical Cent...
# 4         Glendale Memorial Hospital And Health Center
# ..                                                 ...
# 160        Southern California Hospital at Culver City
# 161        Southern California Hospital at Culver City
# 162        Southern California Hospital at Culver City
# 163          Southern California Hospital at Hollywood
# 164          Southern California Hospital at Hollywood
#
#                      addrln1 addrln2         city  ...  \
# 0         1812 Verdugo Blvd.     NaN     Glendale  ...
# 1           2000 Stadium Way     NaN  Los Angeles  ...
# 2            150 W. Route 66     NaN     Glendora  ...
# 3        4101 Torrance Blvd.     NaN     Torrance  ...
# 4       1420 S. Central Ave.     NaN     Glendale  ...
# ..                       ...     ...          ...  ...
# 160        3828 Delmas Ter       NaN  Culver City  ...
# 161        3828 Delmas Ter       NaN  Culver City  ...
# 162        3828 Delmas Ter       NaN  Culver City  ...
# 163  6245 De Longpre Avenue      NaN    Hollywood  ...
# 164  6245 De Longpre Avenue      NaN    Hollywood  ...
#
#                                        link use_type   latitude   longitude  \
# 0      http://egis3.lacounty.gov/lms/?p=560  publish  34.204530 -118.216023
# 1      http://egis3.lacounty.gov/lms/?p=561  publish  34.075693 -118.248312
# 2      http://egis3.lacounty.gov/lms/?p=568  publish  34.127307 -117.865075
# 3      http://egis3.lacounty.gov/lms/?p=569  publish  33.838634 -118.357113
# 4      http://egis3.lacounty.gov/lms/?p=570  publish  34.128058 -118.257443
# ..                                      ...      ...        ...         ...
# 160  http://egis3.lacounty.gov/lms/?p=80733  publish  34.023195 -118.396943
# 161  http://egis3.lacounty.gov/lms/?p=80733  publish  34.023195 -118.396943
# 162  http://egis3.lacounty.gov/lms/?p=80733  publish  34.023195 -118.396943
# 163  http://egis3.lacounty.gov/lms/?p=80738  publish  34.096445 -118.325144
# 164  http://egis3.lacounty.gov/lms/?p=80738  publish  34.096445 -118.325144
#
#                  date_updated email  dis_status       POINT_X       POINT_Y  \
# 0   2016-01-29 10:45:00+00:00   NaN         NaN  6.496353e+06  1.896883e+06
# 1   2016-01-21 15:56:47+00:00   NaN         NaN  6.486475e+06  1.850019e+06
# 2   2016-01-22 14:39:39+00:00   NaN         NaN  6.602504e+06  1.868737e+06
# 3   2016-01-27 11:34:40+00:00   NaN         NaN  6.453221e+06  1.763848e+06
# 4   2016-01-22 16:10:02+00:00   NaN         NaN  6.483758e+06  1.869083e+06
# ..                        ...   ...         ...           ...           ...
# 160 2016-02-02 13:21:01+00:00   NaN         NaN  6.441390e+06  1.831059e+06
# 161 2016-02-02 13:21:01+00:00   NaN         NaN  6.441390e+06  1.831059e+06
# 162 2016-02-02 13:21:01+00:00   NaN         NaN  6.441390e+06  1.831059e+06
# 163 2016-02-03 11:38:45+00:00   NaN         NaN  6.463232e+06  1.857638e+06
# 164 2016-02-03 11:38:45+00:00   NaN         NaN  6.463232e+06  1.857638e+06
#
#                         geometry
# 0    POINT (-118.21602 34.20453)
# 1    POINT (-118.24831 34.07569)
# 2    POINT (-117.86507 34.12731)
# 3    POINT (-118.35711 33.83863)
# 4    POINT (-118.25744 34.12806)
# ..                           ...
# 160  POINT (-118.39694 34.02320)
# 161  POINT (-118.39694 34.02320)
# 162  POINT (-118.39694 34.02320)
# 163  POINT (-118.32514 34.09645)
# 164  POINT (-118.32514 34.09645)
#
# [165 rows x 29 columns]

# %%
hospital['cat1'].equals(hospital['cat2'])
# Out:
# False

# %%
hospital.columns
# Out:
# Index(['OBJECTID', 'source', 'ext_id', 'cat1', 'cat2', 'cat3', 'org_name',
#        'Name', 'addrln1', 'addrln2', 'city', 'state', 'hours', 'phones', 'url',
#        'info1', 'info2', 'post_id', 'description', 'zip', 'link', 'use_type',
#        'latitude', 'longitude', 'date_updated', 'email', 'dis_status',
#        'POINT_X', 'POINT_Y', 'geometry'],
#       dtype='object')

# %%
# dropping the date update column
hospital = hospital.drop(columns='date_updated', axis =1)

# %%
hospital.dis_status.unique()
# Out:
# array([nan])

# %%
hospital = hospital.drop(columns='dis_status', axis =1)

# %%
hospital = hospital.drop(columns='email', axis =1)

# %%
hospital = hospital.drop(columns='phones', axis =1)

# %%
hospital.shape
# Out:
# (165, 26)

# %%
hospital = hospital.drop(columns='url', axis =1)

# %%
hospital = hospital.drop(columns='source', axis =1)

# %%
hospital = hospital.drop(columns='OBJECTID', axis =1)

# %%
hospital.columns
# Out:
# Index(['ext_id', 'cat1', 'cat2', 'cat3', 'org_name', 'Name', 'addrln1',
#        'addrln2', 'city', 'state', 'hours', 'info1', 'info2', 'post_id',
#        'description', 'zip', 'link', 'use_type', 'latitude', 'longitude',
#        'POINT_X', 'POINT_Y', 'geometry'],
#       dtype='object')

# %%
hospital.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 23 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ext_id       13 non-null     object
#  1   cat1         165 non-null    object
#  2   cat2         165 non-null    object
#  3   cat3         110 non-null    object
#  4   org_name     133 non-null    object
#  5   Name         165 non-null    object
#  6   addrln1      163 non-null    object
#  7   addrln2      11 non-null     object
#  8   city         163 non-null    object
#  9   state        163 non-null    object
#  10  hours        158 non-null    object
#  11  info1        10 non-null     object
#  12  info2        3 non-null      object
#  13  post_id      165 non-null    int64
#  14  description  165 non-null    object
#  15  zip          163 non-null    object
#  16  link         165 non-null    object
#  17  use_type     165 non-null    object
#  18  latitude     165 non-null    float64
#  19  longitude    165 non-null    float64
#  20  POINT_X      165 non-null    float64
#  21  POINT_Y      165 non-null    float64
#  22  geometry     165 non-null    geometry
# dtypes: float64(4), geometry(1), int64(1), object(17)
# memory usage: 29.8+ KB

# %%
hospital['ext_id'].values
# Out:
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 'CA86',
#        'CA86', 'CA86', '1732851', '1732851', '1660655', '1732541',
#        '1732731', '1660298', '1732699', '2130123', '1724329', '2084607',
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan], dtype=object)

# %%
hospital = hospital.drop(columns='ext_id', axis =1)

# %%
# check for null values
hospital.isnull().sum()
# Out:
# cat1             0
# cat2             0
# cat3            55
# org_name        32
# Name             0
# addrln1          2
# addrln2        154
# city             2
# state            2
# hours            7
# info1          155
# info2          162
# post_id          0
# description      0
# zip              2
# link             0
# use_type         0
# latitude         0
# longitude        0
# POINT_X          0
# POINT_Y          0
# geometry         0
# dtype: int64

# %%
print(type(hospital))
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>

# %%
# removing null values from cat3, org_name, addrln1, city, state, hours, zip
hospital = hospital.dropna(subset=['cat3', 'org_name', 'addrln1', 'city', 'state', 'hours', 'zip'])

# %%
hospital
# Out:
#                          cat1                           cat2  \
# 0    Health and Mental Health  Hospitals and Medical Centers
# 1    Health and Mental Health  Hospitals and Medical Centers
# 2    Health and Mental Health  Hospitals and Medical Centers
# 3    Health and Mental Health  Hospitals and Medical Centers
# 4    Health and Mental Health  Hospitals and Medical Centers
# ..                        ...                            ...
# 146  Health and Mental Health  Hospitals and Medical Centers
# 155  Health and Mental Health  Hospitals and Medical Centers
# 156  Health and Mental Health  Hospitals and Medical Centers
# 158  Health and Mental Health  Hospitals and Medical Centers
# 159  Health and Mental Health  Hospitals and Medical Centers
#
#                      cat3                                           org_name  \
# 0           911 Receiving
# 1    Respiratory Hospital
# 2           911 Receiving
# 3           911 Receiving  Providence Little  Company of Mary Medical Center
# 4           911 Receiving
# ..                    ...                                                ...
# 146            Acute Care                                   Kindred Hospital
# 155         911 Receiving                                             Verity
# 156            Acute Care                                             Verity
# 158         911 Receiving                          Prime Healthcare Services
# 159            Acute Care                          Prime Healthcare Services
#
#                                                   Name  \
# 0                               Verdugo Hills Hospital
# 1    Barlow Respiratory Hospital - Los Angeles (Mai...
# 2                          Glendora Community Hospital
# 3    Providence Little Company Of Mary Medical Cent...
# 4         Glendale Memorial Hospital And Health Center
# ..                                                 ...
# 146                    Kindred Hospital - Baldwin Park
# 155                       Saint Vincent Medical Center
# 156                       Saint Vincent Medical Center
# 158                       San Dimas Community Hospital
# 159                       San Dimas Community Hospital
#
#                        addrln1 addrln2          city state  \
# 0           1812 Verdugo Blvd.     NaN      Glendale    CA
# 1             2000 Stadium Way     NaN   Los Angeles    CA
# 2              150 W. Route 66     NaN      Glendora    CA
# 3          4101 Torrance Blvd.     NaN      Torrance    CA
# 4         1420 S. Central Ave.     NaN      Glendale    CA
# ..                         ...     ...           ...   ...
# 146  14148 Francisquito Avenue     NaN  Baldwin Park    CA
# 155     2131 West Third Street     NaN   Los Angeles    CA
# 156     2131 West Third Street     NaN   Los Angeles    CA
# 158       1350 W Covina Blvd,      NaN     San Dimas    CA
# 159       1350 W Covina Blvd,      NaN     San Dimas    CA
#
#                                                  hours  ... post_id  \
# 0    Administrative hours are Monday through Friday...  ...     560
# 1    Administrative hours are Monday through Friday...  ...     561
# 2                                       24 hours a day  ...     568
# 3                        24 hours a day 7 days at week  ...     569
# 4    Monday through Friday, 9:00am to 5:00pm.  Emer...  ...     570
# ..                                                 ...  ...     ...
# 146                    24 hours a day, 7 days at week.  ...   80707
# 155        GENERAL ACUTE CARE\r\n8:30 a.m. – 8:30 p.m.  ...   80727
# 156        GENERAL ACUTE CARE\r\n8:30 a.m. – 8:30 p.m.  ...   80727
# 158                     24 hours a day, 7 days a week.  ...   80729
# 159                     24 hours a day, 7 days a week.  ...   80729
#
#                                            description     zip  \
# 0    The facility provides health education and hos...   91208
# 1    For more than a century at Barlow Respiratory ...   90026
# 2    Services provided include comprehensive acute ...   91740
# 3    Providence Little Company of Mary Medical Cent...   90503
# 4    Established in 1926, Glendale Memorial Hospita...   91204
# ..                                                 ...     ...
# 146  Our 91-bed transitional care hospital is locat...   91706
# 155  St. Vincent Medical Center is committed to imp...   90057
# 156  St. Vincent Medical Center is committed to imp...   90057
# 158  <strong>San Dimas Community Hospital</strong> ...  91773
# 159  <strong>San Dimas Community Hospital</strong> ...  91773
#
#                                        link use_type   latitude   longitude  \
# 0      http://egis3.lacounty.gov/lms/?p=560  publish  34.204530 -118.216023
# 1      http://egis3.lacounty.gov/lms/?p=561  publish  34.075693 -118.248312
# 2      http://egis3.lacounty.gov/lms/?p=568  publish  34.127307 -117.865075
# 3      http://egis3.lacounty.gov/lms/?p=569  publish  33.838634 -118.357113
# 4      http://egis3.lacounty.gov/lms/?p=570  publish  34.128058 -118.257443
# ..                                      ...      ...        ...         ...
# 146  http://egis3.lacounty.gov/lms/?p=80707  publish  34.063033 -117.967521
# 155  http://egis3.lacounty.gov/lms/?p=80727  publish  34.063818 -118.273655
# 156  http://egis3.lacounty.gov/lms/?p=80727  publish  34.063818 -118.273655
# 158  http://egis3.lacounty.gov/lms/?p=80729  publish  34.097612 -117.834659
# 159  http://egis3.lacounty.gov/lms/?p=80729  publish  34.097612 -117.834659
#
#           POINT_X       POINT_Y                     geometry
# 0    6.496353e+06  1.896883e+06  POINT (-118.21602 34.20453)
# 1    6.486475e+06  1.850019e+06  POINT (-118.24831 34.07569)
# 2    6.602504e+06  1.868737e+06  POINT (-117.86507 34.12731)
# 3    6.453221e+06  1.763848e+06  POINT (-118.35711 33.83863)
# 4    6.483758e+06  1.869083e+06  POINT (-118.25744 34.12806)
# ..            ...           ...                          ...
# 146  6.571507e+06  1.845321e+06  POINT (-117.96752 34.06303)
# 155  6.478789e+06  1.845718e+06  POINT (-118.27365 34.06382)
# 156  6.478789e+06  1.845718e+06  POINT (-118.27365 34.06382)
# 158  6.611727e+06  1.857944e+06  POINT (-117.83466 34.09761)
# 159  6.611727e+06  1.857944e+06  POINT (-117.83466 34.09761)
#
# [100 rows x 22 columns]

# %%
hospital['info1'].values
hospital['info2'].values
# Out:
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, '864', '864', nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan], dtype=object)

# %%
# info1 and info2 have number of bed spaces but have a lot of missing values and imputation wouldn't be a good idea on this
hospital = hospital.drop(columns=['info1', 'info2'], axis = 1)

# %%
hospital.shape
# Out:
# (100, 20)

# %%
hospital['addrln2'].values
# Out:
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        'Mail Stop #59', 'Mail Stop #59', 'Mail Stop #59', nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan], dtype=object)

# %%
# dropping the addrln2 column
hospital = hospital.drop(columns='addrln2', axis =1)

# %%
hospital.shape
# Out:
# (100, 19)

# %%
hospital.plot(figsize=(10,10), color='#3B3C6E')
# Out:
# <Axes: >

# %% [markdown]
# ## Histogram Plot

# %%
hospital.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 100 entries, 0 to 159
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   cat1         100 non-null    object
#  1   cat2         100 non-null    object
#  2   cat3         100 non-null    object
#  3   org_name     100 non-null    object
#  4   Name         100 non-null    object
#  5   addrln1      100 non-null    object
#  6   city         100 non-null    object
#  7   state        100 non-null    object
#  8   hours        100 non-null    object
#  9   post_id      100 non-null    int64
#  10  description  100 non-null    object
#  11  zip          100 non-null    object
#  12  link         100 non-null    object
#  13  use_type     100 non-null    object
#  14  latitude     100 non-null    float64
#  15  longitude    100 non-null    float64
#  16  POINT_X      100 non-null    float64
#  17  POINT_Y      100 non-null    float64
#  18  geometry     100 non-null    geometry
# dtypes: float64(4), geometry(1), int64(1), object(13)
# memory usage: 15.6+ KB

# %%
# Select the column you want to plot
column = hospital['post_id']

# Plot the histogram
plt.hist(column, bins=20, color='blue', edgecolor='black')

# Add labels and title to the plot
plt.xlabel('ID')
plt.ylabel('Frequency')
plt.title('Histogram of Your Column')

# Show the plot
plt.show()

# %%
# there is a big variation in the values in the post id- maybe these ids are tied with location like zip code

# %% [markdown]
# ## Scatter plot

# %%
# Plot the scatter plot
plt.scatter(hospital['longitude'], hospital['latitude'], color='blue', edgecolor='black')

# Add labels and title to the plot
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Scatter Plot of Latitude and Longitude')

# Show the plot
plt.show()

# %% [markdown]
# ## Map using Folium

# %%
# import the library
import folium

# # Make an empty map
m = folium.Map(location=[20,0], tiles="OpenStreetMap", zoom_start=2)

# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_548c026e00d43ee9bb86c17f2dbb586d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_548c026e00d43ee9bb86c17f2dbb586d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_548c026e00d43ee9bb86c17f2dbb586d = L.map(
#                 &quot;map_548c026e00d43ee9bb86c17f2dbb586d&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e95e03426fa01841f98693457c91ce65 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_548c026e00d43ee9bb86c17f2dbb586d);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# add marker one by one on the map
for i in range(0,len(hospital)):
   folium.Marker(
      location=[hospital.iloc[i]['latitude'], hospital.iloc[i]['longitude']],
      popup=hospital.iloc[i]['city'],
   ).add_to(m)

# Show the map again
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_548c026e00d43ee9bb86c17f2dbb586d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_548c026e00d43ee9bb86c17f2dbb586d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_548c026e00d43ee9bb86c17f2dbb586d = L.map(
#                 &quot;map_548c026e00d43ee9bb86c17f2dbb586d&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e95e03426fa01841f98693457c91ce65 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_548c026e00d43ee9bb86c17f2dbb586d);
#
#
#             var marker_280514421746a09e036da2049d181c37 = L.marker(
#                 [34.2045296, -118.21602345],
#                 {}
#             ).addTo(map_548c026e00d43ee9bb86c17f2dbb586d);
#
#
#         var popup_3be664b0f05b8c2b4a795b2ce0ff87d0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e6df5f9d4a6acf6d5e38b59d544ed118 = $(`&lt;div id=&quot;html_e6df5f9d4a6acf6d5e38b59d544ed118&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Glendale&lt;/div&gt;`)[0];
#                 popup_3be664b0f05b8c2b4a795b2ce0ff87d0.setContent(html_e6df5f9d4a6acf6d5e38b59d544ed118);
#
#
#
#         marker_280514421746a09e036da2049d181c37.bindPopup(popup_3be664b0f05b8c2b4a795b2ce0ff87d0)
#         ;
#
#
#
#
#             var marker_77f08af4e3d10c8942707a87b2709186 = L.marker(
#                 [34.07569271, -118.24831157],
#                 {}
#             ).addTo(map_548c026e00d43ee9bb86c17f2dbb586d);
#
#
#         var popup_027a0c770e9a8f140989e064bfa030b6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_585391750f008b06cd6bcafbdb89934c = $(`&lt;div id=&quot;html_585391750f008b06cd6bcafbdb89934c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Los Angeles&lt;/div&gt;`)[0];
#                 popup_027a0c770e9a8f140989e064bfa030b6.setContent(html_585391750f008b06cd6bcafbdb89934c);
#
#
#
#         marker_77f08af4e3d10c8942707a87b2709186.bindPopup(popup_027a0c770e9a8f140989e064bfa030b6)
#         ;
#
#
#
#
#             var marker_a49159875617dfd632c35fd51a880bc5 = L.marker(
#                 [34.1273073, -117.8650746],
#                 {}
#             ).addTo(map_548c026e00d43ee9bb86c17f2dbb586d);
#
#
#         var popup_fbc6ce03b758ebc641c8bdfe5d0cc91e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9646643a0fdb94b9fed40de7b4124efc = $(`&lt;div id=&quot;html_9646643a0fdb94b9fed40de7b4124efc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Glendora&lt;/div&gt;`)[0];
#                 popup_fbc6ce03b758ebc641c8bdfe5d0cc91e.setContent(html_9646643a0fdb94b9fed40de7b4124efc);
#
#
#
#         marker_a49159875617dfd632c35fd51a880bc5.bindPopup(popup_fbc6ce03b758ebc641c8bdfe5d0cc91e)
#         ;
#
#
#
#
#             var marker_41bd5efff7ba05c92405bf85a597fec8 = L.marker(
#                 [33.83863425, -118.357113],
#                 {}
#             ).addTo(map_548c026e00d43ee9bb86c17f2dbb586d);
#
#
#         var popup_4029a79ebd5a1b108e70a3758ea1b839 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_578567b81d05aad7b9c9f60d3785bcc3 = $(`&lt;div id=&quot;html_578567b81d05aad7b9c9f60d3785bcc3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Torrance&lt;/div&gt;`)[0];
#                 popup_4029a79ebd5a1b108e70a3758ea1b839.setContent(html_578567b81d05aad7b9c9f60d3785bcc3);
#
#
#
#         marker_41bd5efff7ba05c92405bf85a597fec8.bindPopup(popup_4029a79ebd5a1b108e70a3758ea1b839)
#         ;
#
#
#
#
#             var marker_3aa395a374d2511e5cf94e5387f594c6 = L.marker(
#                 [34.12805844, -118.25744298],
#                 {}
#             ).addTo(map_548c026e00d43ee9bb86c17f2dbb586d);
#
#
#         var popup_6d65e89e07dd0e218710a19bd71aaff3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9904b58599bec4b60b237049a8577033 = $(`&lt;div id=&quot;html_9904b58599bec4b60b237049a8577033&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Glendale&lt;/div&gt;`)[0];
#                 popup_6d65e89e07dd0e218710a19bd71aaff3.setContent(html_9904b58599bec4b60b237049a8577033);
#
#
#
#         marker_3aa395a374d2511e5cf94e5387f594c6.bindPopup(popup_6d65e89e07dd0e218710a19bd71aaff3)
#         ;
#
#
#
#
#             var marker_78812380644780dd57d422ec35038e73 = L.marker(
#                 [34.0762194, -118.38103835],
#                 {}
